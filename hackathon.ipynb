# %% [markdown]
# <a href="https://colab.research.google.com/github/slivering/chess_browser/blob/main/hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# First comment!
